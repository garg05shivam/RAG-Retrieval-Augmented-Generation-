# %% [markdown]
# ### Data ingestion

# %%
# Document Structure
from langchain_core.documents import Document

# %%
doc=Document(
    page_content="this is the main text content I am using to create RAG",
    metadata={
        "source": "example.com",
        "page": 1,
        "author": "Shivam Garg",
        "date_created": "2026-05-13"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.com', 'page': 1, 'author': 'Shivam Garg', 'date_created': '2026-05-13'}, page_content='this is the main text content I am using to create RAG')

# %%
## creat simple txt file
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
### Textloader

from langchain_community.document_loaders import TextLoader
loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
### Directory Loader
from langchain_community.document_loaders import DirectoryLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", ## Pattern to match files  
    loader_cls= TextLoader, ##loader class to use
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=False

)

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n    \n    \n    '),
#  Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
##for pdf
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader
from langchain_community.document_loaders import DirectoryLoader

dir_loader = DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf",
    loader_cls=PyMuPDFLoader,
    show_progress=False
)

pdf_documents = dir_loader.load()

pdf_documents
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-11-30T17:00:08+00:00', 'source': '..\\data\\pdf\\PaPer-Final.pdf', 'file_path': '..\\data\\pdf\\PaPer-Final.pdf', 'total_pages': 5, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-11-30T17:00:08+00:00', 'trapped': '', 'modDate': 'D:20251130170008Z', 'creationDate': 'D:20251130170008Z', 'page': 0}, page_content='BiLSTM-based Language Identification in\nCode-Switched Social Media Text\nShouiya Tayal\nComputer Science and Engineering Department\nLovely Professional University\nPhagwara, India\nshouriyatayal1234@gmail.com\nShivam Garg\nComputer Science and Engineering Department\nLovely Professional University\nPhagwara, India\ngarg05shivam@gmail.com\nN N Ajay Kumar\nComputer Science and Engineering Department\nLovely Professional University\nPhagwara, India\nnagaajaykumar19@gmail.com\nEnjula Uchoi\nComputer Science and Engineering Department\nLovely Professional University\nPhagwara, India\nenjula.29634@lpu.co.in\nAbstract—Code-switching, the practice of alternating between\nlanguages within a conversation or even within a single sentence,\nis common in multilingual social media posts. Accurate word-level\nlanguage identification (LID) in such code-switched text is crucial\nfor downstream NLP tasks (e.g., translation, POS tagging), but it\nis challenging due to noise, informal spelling, and lexical overlap\nbetween languages. We propose a bidirectional Long Short-Term\nMemory (BiLSTM) network that integrates character-level and\nword-level representations to label each token as English, the\nother language (Hindi or Spanish), or Other. Experiments on\nbenchmark English–Hindi and English–Spanish Twitter datasets\ndemonstrate that our BiLSTM model substantially outperforms\ntraditional baselines. Specifically, it achieves an overall accuracy\nof 96.8%, compared to 89.2% for an SVM and 91.5% for\na CRF classifier. We present a detailed error analysis: noisy\ntransliteration and ambiguous context at switch points are major\nsources of error. Our results show that deep contextual models\ncan effectively capture the patterns of code-switching in noisy\nsocial text. The code and data will be made available for\nreproducibility.\nIndex Terms—Code-Switching, Language Identification, BiL-\nSTM, Social Media Text, Multilingual NLP, Deep Learning\nI. INTRODUCTION\nCode-switching refers to the use of multiple languages\nwithin the same utterance or discourse [1]. It is a widespread\nphenomenon in informal social media communication in mul-\ntilingual communities (e.g., India, Latin America) [6]. For\nexample, Hindi-English bilinguals often mix Hindi phrases\nwith English words in a single tweet or sentence. While such\nmixed-language data is rich in sociolinguistic information,\nit poses challenges for NLP systems. In particular, standard\nmonolingual tools (e.g., part-of-speech taggers, parsers) typi-\ncally assume a single language and break down when faced\nwith code-switched text. Word-level language identification\n(LID) is a critical first step in processing code-switched\ncontent, as it enables subsequent modules to apply the correct\nlanguage model for each token [4].\nHowever, token-level LID for code-switched social media\ntext is inherently difficult. Text from Twitter or Facebook is\noften noisy and informal (slang, spelling variants, repetitive\ncharacters), and many tokens may be ambiguous or transliter-\nated [7]. For example, Hindi words appear in Roman script,\nand English and Spanish share similar vocabulary due to Latin\nroots, leading to lexical overlap [2]. These factors make it\nhard for simple classifiers to distinguish languages. Recently,\nneural sequence models such as BiLSTM have shown promise\nin capturing context and subword patterns [5], [8]. Motivated\nby these advances, we develop a BiLSTM-based LID system\ntailored to code-switched social media text.\nIn this ...
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-11-30T17:00:08+00:00', 'source': '..\\data\\pdf\\PaPer-Final.pdf', 'file_path': '..\\data\\pdf\\PaPer-Final.pdf', 'total_pages': 5, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-11-30T17:00:08+00:00', 'trapped': '', 'modDate': 'D:20251130170008Z', 'creationDate': 'D:20251130170008Z', 'page': 1}, page_content='demonstrates the superiority of our BiLSTM model over\nbaselines, achieving an accuracy of 96.8This finding highlights\nthe value of adopting deep contextual modeling strategies\nin addressing the complexities of code-switched language\nidentification.\nII. RELATED WORK\nThe recent surge in code-switched language identification\nresearch has been driven by the development of advanced neu-\nral models and large-scale datasets. These studies have high-\nlighted the need for contextual information and global sentence\nstructure in code-switching detection. Notably, Nguyen et al.’s\n[3] comprehensive datasets for Hindi-English code-switching\nfrom social media platforms have significantly contributed to\nthis endeavor.\nMoreover, Burchell et al.’s [1] findings on the challenges\nof code-switched language identification in large-scale mul-\ntilingual settings underscore the importance of leveraging\ncontextual information and sentence-level multi-label formu-\nlations. Their work demonstrates that traditional token-level\napproaches can be improved upon by incorporating global\nsentence structure.\nFurthermore, Kargaran et al.’s [4] unsupervised method for\ncode-switching identification using iterative masking strategies\nhas shown promising results in low-resource scenarios, lever-\naging transformer architectures to achieve strong performance\neven without extensive labeled data. Similarly, De Le´on et\nal.’s [2] probing framework reveals that pre-trained language\nmodels can effectively generalize to code-switched text when\nproperly fine-tuned.\nUdawatta et al.’s [5] exploration of prompt-based learning\nfor code-mixed and code-switched text classification highlights\nthe potential of carefully designed prompts in improving\nmodel performance without extensive architectural changes.\nGhafouri et al.’s [7] PinLID dataset for Pinglish language\nidentification underscores the need for language-specific ap-\nproaches in code-switching research.\nRecent advances in transformer-based architectures have\nalso enabled significant improvements in code-switched lan-\nguage identification, as demonstrated by Zhang et al.’s [8]\nproposal of a cross-lingual contextual embeddings approach.\nChen et al.’s [9] investigation into the role of syntactic fea-\ntures in code-switched language identification highlights the\nimportance of incorporating dependency parsing information\nfor improved model performance.\nThe\nexploration\nof\nmeta-learning\nfor\nfew-shot\ncode-\nswitched language identification by Kumar et al.[11] and\nthe comprehensive survey of code-switched Arabic NLP by\nHamed et al.[6] further underscore the evolving landscape\nof code-switching research, emphasizing neural approaches,\nmultilingual capabilities, and robust evaluation frameworks.\nThese studies collectively demonstrate a shift towards more\nnuanced understanding of code-switching detection, highlight-\ning the need for contextual information, global sentence struc-\nture, and language-specific approaches in this domain.\nIII. METHODOLOGY\nIn our proposed language identification model, a hierarchi-\ncal architecture leverages sequential representations to effec-\ntively capture code-switched text complexities. The model’s\nconfiguration can be visualized through Figure ??, which\nillustrates the layer-by-layer processing of tokens. Each token\nwithin the input sequence is processed through two distinct\nsub-networks: one focused on word-level semantics and the\nother emphasizing character-level spelling inform ...
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-11-30T17:00:08+00:00', 'source': '..\\data\\pdf\\PaPer-Final.pdf', 'file_path': '..\\data\\pdf\\PaPer-Final.pdf', 'total_pages': 5, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-11-30T17:00:08+00:00', 'trapped': '', 'modDate': 'D:20251130170008Z', 'creationDate': 'D:20251130170008Z', 'page': 2}, page_content='on the same datasets and evaluated by per-token accuracy on\nheld-out test sets.\nIV. DATASET DESCRIPTION\nWe conduct experiments on code-switched Twitter datasets\ninvolving English mixed with either Hindi or Spanish. For\nEnglish–Hindi, we use the publicly available ICON-2021\ndataset [3], which contains Hindi-English tweets annotated\nwith word-level language tags (Hindi, English, Other) from\nFacebook, Twitter and WhatsApp sources. This dataset con-\ntains approximately 15,000 tokens of annotated text with\ndiverse code-switching patterns.\nFor English–Spanish, we use a recently collected Twitter\ndataset following the annotation framework proposed by De\nLe´on et al. [2]. This corpus contains approximately 5,000\ntweets with token-level language annotations, representing\nnatural code-switching patterns in Spanish-English bilingual\ncommunities.\nIn both datasets, each token is tagged as the content of\nLanguage 1 (English), Language 2 (Hindi or Spanish), or\nOther (named entities, foreign fragments, emoticons, etc.).\nWe combine the two corpora only in some multilingual\nexperiments; otherwise we report results on each language pair\nseparately.\nPreprocessing involves basic normalization: tweets are low-\nercased, hashtags and user mentions are retained as tokens\n(labeled Other), and non-textual tokens (URLs, emoticons)\nare filtered out. We split each dataset into training (80%),\ndevelopment (10%), and test (10%) sets, ensuring that no\ntweet appears in more than one split. Both datasets exhibit the\ntypical code-switching characteristics noted in recent research,\nincluding transliteration challenges and lexical borrowing.\nV. EXPERIMENTS\nWe train the BiLSTM model and baselines on each code-\nswitched dataset. Hyperparameters (e.g., SVM regularization,\nCRF L2 penalty) are tuned on the development set. For the\nBiLSTM, we fix a word embedding size of 100 and char\nembedding size of 50, and run for up to 30 epochs with early\nstopping. We report accuracy on the test set as the evaluation\nmetric (percentage of tokens correctly labeled).\nAs baselines, we use the SVM and CRF classifiers described\nabove. For the SVM we use a linear kernel with C = 1.0. For\nthe CRF we use the CRF++ toolkit with L1/L2 regularization\n(optimized on dev). These baselines represent conventional\napproaches in code-switched LID that remain competitive\nin certain scenarios [7]. We also include an ablation of the\nBiLSTM without character inputs (word embeddings only) to\nmeasure the gain from character-level modeling.\nAll experiments are run five times with different random\nseeds; we report averaged accuracies. Training times vary\n(BiLSTM takes 10 minutes on a GPU for each dataset, while\nCRF/SVM train in under a minute on a CPU). We ensure\nthat all models see the same train/dev/test splits for a fair\ncomparison.\nVI. RESULTS\nA comparative analysis of the BiLSTM model against\ntraditional SVM and CRF approaches highlights the superior\nperformance of the deep recurrent architecture. Specifically,\nFigure 1 displays the accuracy gains achieved by the BiLSTM\nmodel, yielding a notable 5–7% absolute improvement over\nits baselines. The underlying reasons for this advantage can\nbe traced back to the model’s ability to seamlessly blend local\nsub-word patterns with sentence-level contextual information.\nTo further elucidate the BiLSTM model’s performance,\nFigure 2 provides a detailed breakdown of its classification\noutcomes. Notably, the majority of English and Hindi tokens\n ...
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-11-30T17:00:08+00:00', 'source': '..\\data\\pdf\\PaPer-Final.pdf', 'file_path': '..\\data\\pdf\\PaPer-Final.pdf', 'total_pages': 5, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-11-30T17:00:08+00:00', 'trapped': '', 'modDate': 'D:20251130170008Z', 'creationDate': 'D:20251130170008Z', 'page': 3}, page_content='Fig. 1. Accuracy comparison of language ID models on code-switched text.\nThe BiLSTM outperforms SVM and CRF baselines.\nFig. 2. Confusion matrix for the BiLSTM on English–Hindi test data. Rows =\ntrue language, columns = predicted. The model has high precision and recall\nfor each label.\nstructures (long phrases mixing languages) account for about\n20%. The remaining 10% involves named entities or other\nout-of-vocabulary tokens that defy classification. These error\ncategories highlight well-known challenges in CS text: social\nmedia text is unstandardized, and code-switch points often lack\nsufficient context [1].\nFig. 3. Distribution of BiLSTM token errors by type. Most errors come from\nnoisy spelling and ambiguous switch points.\nFinally, Figure 4 plots the BiLSTM accuracy as a function\nof training data size (on a held-out subset). The curve rises\nsteeply with more data and begins to plateau as it approaches\nthe full dataset (reaching our reported 96.8% at 100%). This\nsuggests the model benefits from larger training sets, but even\nwith 50% of the data it achieves over 90%. We also note that\nthe CRF baseline suffers more from data sparsity; reducing\nthe training set by half caused its accuracy to drop by roughly\n10 points, whereas the BiLSTM dropped by about 6 points.\nThis indicates that deep models, while data-hungry, generalize\nslightly better than feature-based models as more data becomes\navailable.\nFig. 4.\nBiLSTM accuracy versus percentage of training data. Accuracy\nimproves with more data, leveling off around 96.8%.\nVII. ERROR ANALYSIS\nInherent limitations in the model’s character encoding can\nresult in mislabeled tokens, particularly those stemming from\nnon-standard transliterations. Notably, variants of Hindi words\nwritten in Roman script, such as “haii” instead of “hai”,\nare often omitted from training datasets. Consequently, when\nencountered during inference, these informal spellings may\ncause the model to misclassify them as Hindi.\nA case in point is the phrase “yeh movie tha amazing”,\nwherein a combination of Hindi and English words is em-\nployed. Specifically, the presence of the Hindi word “yeh”\n(translated to ”this”) alongside the borrowed English term\n”movie” necessitates careful contextual analysis to accurately\nassign labels. However, variations such as the transliterated\nform ”moovii” or the omission of vowels frequently lead to\nclassification errors.\nA second issue is ambiguous context at switch points. Some\nwords exist in both languages (cognates) or are borrowed\n(e.g., “film,” “school,” “train”). If a sentence lacks strong\nsurrounding cues, the classifier may guess incorrectly. For\ninstance, the word “school” in a Hindi context (e.g., “vah\nschool gaya”) might be mistakenly tagged as English by a\nbaseline. Our model often uses broader context, but errors still\noccur when the context is minimal. This aligns with recent\nobservations that shared vocabulary makes Spanish-English\nLID particularly hard [2].\nFinally, complex sentence mixing contributes to errors. Long\ntweets that alternate multiple times between languages (or\ninclude subordinate clauses) can confuse the sequential model,\nespecially if there are few separators (punctuation) between\nsegments. In some cases, named entities or foreign words'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-11-30T17:00:08+00:00', 'source': '..\\data\\pdf\\PaPer-Final.pdf', 'file_path': '..\\data\\pdf\\PaPer-Final.pdf', 'total_pages': 5, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-11-30T17:00:08+00:00', 'trapped': '', 'modDate': 'D:20251130170008Z', 'creationDate': 'D:20251130170008Z', 'page': 4}, page_content='(labeled as Other) are mistaken for the main languages. We\nobserved that “Other” is the least frequent category, and\nerrors often arise from difficulty distinguishing named entities\n(usually labeled as Other) from content words.\nIn summary, our BiLSTM makes relatively few errors, but\nwhen they occur, they are usually due to these phenom-\nena: noisy orthography, near-cognate ambiguity, and tangled\nmultilingual syntax. Addressing these would likely require\nadditional signals (e.g., language-model probabilities, translit-\neration normalization) or more diverse training data.\nVIII. DISCUSSION\nThe experimental results demonstrate the strengths and\nlimitations of our BiLSTM approach. On the positive side, the\nBiLSTM effectively leverages sequential context and character\ninformation, yielding much higher accuracy than standard\nbaselines. This confirms that deep models can learn subtle\nmorphological cues (via the character-level BiLSTM) and\ncontextual disambiguation that rule-based or shallow meth-\nods miss. The model is flexible and language-agnostic; in\nprinciple, it can be applied to any language pair with min-\nimal modifications to data and labels. Its strong performance\n(96.8%) suggests it is viable for real-world applications, such\nas preprocessing code-switched social media for sentiment\nanalysis or translation.\nHowever, several limitations are apparent. First, the BiL-\nSTM still requires substantial annotated data; its performance\ndrops with less training data (Figure 4). In low-resource\nsettings, approaches like MaskLID [4] that use unsupervised\nmethods may be more robust. Second, the model occasionally\nmislabels edge cases (noisy spellings, foreign tokens). Incor-\nporating additional modules (e.g., a transliteration normalizer\nor a gazetteer for named entities) could help. Third, our model\ntreats language identification as a purely token-level tagging\nproblem. Recent work [1] suggests that considering sentence-\nlevel structure (multi-label LID) and global context may\nfurther improve the detection of code-switching. Extending our\napproach to such settings would be an interesting direction.\nFinally, our findings have broader implications. Accurate\nCS LID lays the groundwork for better performance on down-\nstream tasks (e.g., part-of-speech tagging, parsing) in mixed-\nlanguage scenarios. The fact that modern neural models excel\nat this suggests that future multilingual NLP pipelines should\nexplicitly incorporate language-IDentification layers for social\nmedia data. Nonetheless, careful error analysis shows that\nmany challenges remain inherently linguistic (code-mixing\nphenomena) rather than purely technical, echoing survey ob-\nservations in the literature [6].\nIX. CONCLUSION\nA recent investigation into code-switched social media text\nhas shed light on the efficacy of employing deep recurrent\narchitectures for language identification at the word level. By\nleveraging both character-level and word-level embeddings in\ntandem, our model outperforms conventional SVM and CRF\nbaselines in tackling English–Hindi and English–Spanish Twit-\nter datasets. This achievement underscores the significance\nof incorporating contextual information and subword features\nin mitigating the complexities of code-switching. Through a\nthorough examination of error patterns, we have pinpointed\nthe primary sources of mistakes (transliteration errors, word\nambiguity, and intricate syntax), thereby informing potential\navenues for future refine ...
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-03-31T15:15:06+05:30', 'source': '..\\data\\pdf\\R2OM66A01_Assignment - Design Problem(s)_MKT905_MKT 905.pdf', 'file_path': '..\\data\\pdf\\R2OM66A01_Assignment - Design Problem(s)_MKT905_MKT 905.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': 'HRUDAI GOUD', 'subject': '', 'keywords': '', 'moddate': '2026-03-31T15:15:06+05:30', 'trapped': '', 'modDate': "D:20260331151506+05'30'", 'creationDate': "D:20260331151506+05'30'", 'page': 0}, page_content='Annexure-V- Cover Page for Academic Tasks \n \nCourse Code:  MKT905 \nCourse Title: SEARCH ENGINE OPTIMIZATION \nCourse Instructor: DR. ATUL SHARMA \nAcademic Task No.: \nCA 1 \n                    Academic Task Title: SEO \nDate of Allotment: 13-03-26 \nDate of submission: 31-03-26 \nStudent’s Roll no:  01 \nStudent’s Reg. no: 12312888 \nEvaluation Parameters: (Parameters on which student is to be evaluated- To be mentioned by \nstudents as specified at the time of assigning the task by the instructor) \n \n \nLearning Outcomes: (Student to write briefly about learnings obtained from the \nacademic tasks) \n \n \nDeclaration: \nI declare that this Assignment is my individual work. I have not copied it from any other \nstudent’s work or from any other source except where due acknowledgement is made \nexplicitly in the text, nor has any part been written for me by any other person. \n \nStudent’s Singnature: \nO HRUDAI GOUD \n \n \n \n \n \n \n \n \n \n \n \n \nPage 5 of 7'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-03-31T15:15:06+05:30', 'source': '..\\data\\pdf\\R2OM66A01_Assignment - Design Problem(s)_MKT905_MKT 905.pdf', 'file_path': '..\\data\\pdf\\R2OM66A01_Assignment - Design Problem(s)_MKT905_MKT 905.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': 'HRUDAI GOUD', 'subject': '', 'keywords': '', 'moddate': '2026-03-31T15:15:06+05:30', 'trapped': '', 'modDate': "D:20260331151506+05'30'", 'creationDate': "D:20260331151506+05'30'", 'page': 1}, page_content='Evaluator’scomments (For Instructor’s use only) \n \nGeneral Observations \nSuggestions for \nImprovement \nBest part of Assignment \n \nEvaluator’s Signature and Date: \n \nMarks Obtained:  \n \nMax. Marks:  \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \nPage 7 of 7'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-03-31T15:15:06+05:30', 'source': '..\\data\\pdf\\R2OM66A01_Assignment - Design Problem(s)_MKT905_MKT 905.pdf', 'file_path': '..\\data\\pdf\\R2OM66A01_Assignment - Design Problem(s)_MKT905_MKT 905.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': 'HRUDAI GOUD', 'subject': '', 'keywords': '', 'moddate': '2026-03-31T15:15:06+05:30', 'trapped': '', 'modDate': "D:20260331151506+05'30'", 'creationDate': "D:20260331151506+05'30'", 'page': 2}, page_content='1. Introduction \nThe project titled ‘Sabari Trends’ is centered on creating a modern, exclusive men’s wear e- \ncommerce platform using the Wix website builder. Designed to offer a seamless, user- \nfriendly, and visually appealing shopping experience, the website caters to the growing \ndemand for stylish, comfortable, and affordable men’s fashion. Drawing inspiration from \nMyntra, one of India’s most successful unicorn startups, Sabari Trends integrates innovative \ndesign, smooth navigation, and responsive layouts to ensure customer satisfaction. The \nproject not only emphasizes aesthetics and functionality but also leverages AI-driven \nmarketing and SEO strategies to enhance online visibility and digital performance, making it \na complete modern eCommerce solution. \n \n \n \n2. Website Design Process \nThe website Sabari Trends was designed using the Wix platform for its simple drag-and- \ndrop interface and advanced eCommerce capabilities. The homepage features a split-banner \nlayout showcasing modern men’s fashion with bold, high-quality visuals that immediately \ncapture attention. The brand logo, styled in red with white typography, appears \nprominently at the top center, creating a clean and professional look. The site’s primary \ncolor palette includes red (#E53935) for highlights, white (#FFFFFF) for background \nclarity, and black/gray accents (#212121) for text and contrast. The top navigation bar \nprovides easy access to Men, Accessories, and Discover sections, along with quick links for \nWishlist, Cart, and User Account. The homepage also includes a promotional banner offering \n“25% OFF for new users” with a discount code, adding an engaging marketing touch. \nAll pages—Home, Shop, About, and Contact—are optimized for mobile responsiveness and \nuser-friendly navigation, ensuring a smooth browsing experience across all devices. \n \nWEBSITE LINK:- https://hrudaigoud.wixsite.com/sabari-trends-1'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-03-31T15:15:06+05:30', 'source': '..\\data\\pdf\\R2OM66A01_Assignment - Design Problem(s)_MKT905_MKT 905.pdf', 'file_path': '..\\data\\pdf\\R2OM66A01_Assignment - Design Problem(s)_MKT905_MKT 905.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': 'HRUDAI GOUD', 'subject': '', 'keywords': '', 'moddate': '2026-03-31T15:15:06+05:30', 'trapped': '', 'modDate': "D:20260331151506+05'30'", 'creationDate': "D:20260331151506+05'30'", 'page': 3}, page_content='3. Analytics Setup \nTo monitor website performance and user engagement, the inbuilt Wix Analytics \nDashboard was utilized instead of Google Analytics. The Wix analytics tool provides real- \ntime insights into visitor traffic, popular pages, session duration, and user behavior directly \nwithin the Wix interface. This feature simplified the tracking process by automatically \ncollecting key data such as site visits, top-performing products, and traffic sources without \nthe need for external integrations. Through these analytics, the project team was able to \nevaluate website reach and understand audience preferences, helping improve marketing \ndecisions and content strategy. \nScreenshot Placeholder: Insert Wix Analytics Dashboard Screenshot Here \n \n \n \n4. Social Media Integration \nTo promote Sabari Trends and reach a broader audience, social media profiles were created \nand actively linked to the website through clickable icons on the homepage. The platforms \nused include Instagram, Facebook, and X (formerly Twitter) — each serving as a channel to \nshowcase new arrivals, fashion tips, and promotional campaigns.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-03-31T15:15:06+05:30', 'source': '..\\data\\pdf\\R2OM66A01_Assignment - Design Problem(s)_MKT905_MKT 905.pdf', 'file_path': '..\\data\\pdf\\R2OM66A01_Assignment - Design Problem(s)_MKT905_MKT 905.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': 'HRUDAI GOUD', 'subject': '', 'keywords': '', 'moddate': '2026-03-31T15:15:06+05:30', 'trapped': '', 'modDate': "D:20260331151506+05'30'", 'creationDate': "D:20260331151506+05'30'", 'page': 4}, page_content='INSTGRAM :- \n \n \nFACEBOOK:-'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-03-31T15:15:06+05:30', 'source': '..\\data\\pdf\\R2OM66A01_Assignment - Design Problem(s)_MKT905_MKT 905.pdf', 'file_path': '..\\data\\pdf\\R2OM66A01_Assignment - Design Problem(s)_MKT905_MKT 905.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': 'HRUDAI GOUD', 'subject': '', 'keywords': '', 'moddate': '2026-03-31T15:15:06+05:30', 'trapped': '', 'modDate': "D:20260331151506+05'30'", 'creationDate': "D:20260331151506+05'30'", 'page': 5}, page_content='X:- \n \n \n \n \n \n5. SEO Strategy \nTo enhance the online visibility of Sabari Trends, several Search Engine Optimization (SEO) \ntechniques were implemented using Wix’s built-in marketing tools. Relevant keywords such \nas “men’s wear online,” “streetwear for men,” “modern menswear,” and “affordable fashion for \nmen” were integrated across product pages, headings, and meta descriptions to improve \nsearch rankings. Each product image was optimized with alt text descriptions — for \nexample, “Model wearing a casual checkered overshirt for men” — to ensure better image \nindexing and accessibility. \nAdditionally, the brand’s social media content supported SEO efforts through engaging and \nkeyword-rich captions like: \n“Effortlessly cool, endlessly confident. ³ˇ\n£ This season, redefine casual with our \nsignature checkered overshirt — crafted for comfort, styled for every mood. Pair it. \nLayer it. Own it. #SabariTrends #MensStyle #StreetwearEssentials #ModernMenswear \n#StayStylish”'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-03-31T15:15:06+05:30', 'source': '..\\data\\pdf\\R2OM66A01_Assignment - Design Problem(s)_MKT905_MKT 905.pdf', 'file_path': '..\\data\\pdf\\R2OM66A01_Assignment - Design Problem(s)_MKT905_MKT 905.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': 'HRUDAI GOUD', 'subject': '', 'keywords': '', 'moddate': '2026-03-31T15:15:06+05:30', 'trapped': '', 'modDate': "D:20260331151506+05'30'", 'creationDate': "D:20260331151506+05'30'", 'page': 6}, page_content='This consistent use of targeted hashtags and keywords across platforms helped strengthen \nthe brand’s digital presence, driving both organic traffic and social engagement. \n \n \n \n6. AI-Driven Marketing \nTo enhance digital marketing performance, AI-driven tools were integrated for keyword \noptimization and SEO enhancement. Wix’s AI SEO Assistant was used to analyze content \nrelevance and suggest improvements for meta descriptions, titles, and keyword density. \nAdditionally, ChatGPT was used to generate keyword suggestions and SEO-friendly product \ndescriptions, improving organic search visibility. \n \n \n \n7. Conclusion \nThe development of the Sabari Trends website provided valuable insights into website \ndesign, digital marketing, and eCommerce management. Through the use of Wix tools, AI- \ndriven optimization, and modern branding strategies, the project achieved its goal of \ncreating a functional and engaging online men’s wear store. As a result, the website gained \ninitial visibility through social media integration and SEO improvements, showcasing the \neffectiveness of combining AI and design for digital success.'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 0}, page_content='1\nDr. Sudip Misra\nAssociate Professor\nDepartment of Computer Science and Engineering\nIIT KHARAGPUR\nEmail: smisra@sit.iitkgp.ernet.in\nWebsite: http://cse.iitkgp.ac.in/~smisra/\nSmart Cities and Smart Homes – Part I\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 1}, page_content='Introduction\n\uf0fcA Smart City is-\n\uf0a7An urban system\n\uf0a7Uses Information & Communication Technology (ICT)\n\uf0a7Makes infrastructure more interactive, accessible and efficient.\n\uf0fcNeed for Smart Cities arose due to-\n\uf0a7Rapidly growing urban population\n\uf0a7Fast depleting natural resources\n\uf0a7Changes in environment and climate\n2\nSource: Pellicer, Soledad, et al. "A global perspective of smart cities: A survey." IEEE Seventh International Conference on Innovative Mobile and \nInternet Services in Ubiquitous Computing (IMIS), 2013.\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 2}, page_content='Analogy\nHumans\nSmart Cities\nSkeleton\nBuildings, Industries, People\nSkin\nTransportation, Logistics\nOrgans\nHospital, Police, Banks, Schools\nBrain\nUbiquitously embedded intelligence\nNerves\nDigital telecommunication networks\nSensory Organs\nSensors, Tags\nCognition\nSoftware\n3\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 3}, page_content='Application Focus Areas\n4\n• Competitiveness\nSmart Economy\n• Citizen participation\nSmart Governance\n• Social and Human Capital\nSmart People\n• Transport and ICT\nSmart Mobility\n• Natural resources\nSmart Environment\n• Quality of life\nSmart Living\nSource: Pellicer, Soledad, et al. "A global perspective of smart cities: A survey." IEEE Seventh International Conference on Innovative Mobile and \nInternet Services in Ubiquitous Computing (IMIS), 2013.\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 4}, page_content='Smart Economy\n5\nSource: “Smart Economy”, Project Chapel Hill (Online)\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 5}, page_content='Smart Governance\n6\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 6}, page_content='Smart People\n7\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 7}, page_content='Smart Mobility\n8\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 8}, page_content='Smart Environment\n9\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 9}, page_content='Smart Living\n10\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 10}, page_content='Current Focus Areas\n\uf0fcSmart Homes\n\uf0a7Health monitoring.\n\uf0a7Conservation of resources (e.g. electricity, water, fuel).\n\uf0a7Security and safety.\n\uf0fcSmart Parking Lots\n\uf0a7Auto routing of vehicles to empty slots.\n\uf0a7Auto charging for services provided.\n\uf0a7Detection of vacant slots in the parking lot.\n11\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 11}, page_content='Current Focus Areas (contd.)\n\uf0fcSmart Vehicles\n\uf0a7\nAssistance to drivers during bad weather or low-visibility.\n\uf0a7\nDetection of bad driving patterns or driving under the influence of substances.\n\uf0a7\nAuto alert generation during crashes.\n\uf0a7\nSelf diagnostics.\n\uf0fcSmart Health\n\uf0a7\nLow cost, portable, at-home medical diagnosis kits.\n\uf0a7\nRemote check-ups and diagnosis.\n\uf0a7\nOn-body sensors for effortless and accurate health monitoring.\n\uf0a7\nAuto alert generation in case of emergency medical episodes (e.g. Heart attacks, \nseizures).\n12\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 12}, page_content='Current Focus Areas (contd.)\n\uf0fcPollution and Calamity Monitoring\n\uf0a7Monitoring for weather or man-made based calamities.\n\uf0a7Alert generation in case of above-threshold pollutants in the air or water.\n\uf0a7Resource reallocation and rerouting of services in the event of calamities.\n\uf0fcSmart Energy\n\uf0a7Smart metering systems.\n\uf0a7Smart energy allocation and distribution system.\n\uf0a7Incorporation of traditional and renewable sources of energy in the same \ngrid.\n13\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 13}, page_content='Current Focus Areas (contd.)\n\uf0fcSmart Agriculture\n\uf0a7Automatic detection of plant water stress.\n\uf0a7Monitoring of crop health status.\n\uf0a7Auto detection of crop infection.\n\uf0a7Auto application of fertilizers and pesticides.\n\uf0a7Scheduling harvesting and arranging proper transfer of harvests to \nwarehouses or markets.\n14\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 14}, page_content='Technological Focus Areas\n15\n• Mobile devices, Sensors, Architecture\nData Collection\n• Radios, Networking, Topologies\nData Transmission\n• Local storage, Data warehouses\nData Storage\n• Data cleaning, Analytics, Prediction\nData Processing\nSource: Pellicer, Soledad, et al. "A global perspective of smart cities: A survey." IEEE Seventh International Conference on Innovative Mobile and \nInternet Services in Ubiquitous Computing (IMIS), 2013.\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 15}, page_content='IoT Challenges in Smart Cities\n\uf0fcSecurity and Privacy\n\uf0a7Exposure to attacks (e.g. cross-site scripting, side channel, etc.).\n\uf0a7Exposure to vulnerabilities.\n\uf0a7Multi-tenancy induces the risk of data leakage.\n\uf0fcHeterogeneity\n\uf0a7Integration of varying hardware platforms and specifications.\n\uf0a7Integration of different radio specifications.\n\uf0a7Integration of various software platforms.\n\uf0a7Accommodating varying user requirements.\n16\nSource: Arasteh, H., et al. "Iot-based smart cities: A survey." IEEE 16th International Conference on Environment and Electrical \nEngineering (EEEIC), 2016.\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 16}, page_content='IoT Challenges in Smart Cities (contd.)\n\uf0fcReliability\n\uf0a7Unreliable communication due to vehicle mobility.\n\uf0a7Device failures still significant\n\uf0fcLarge scale\n\uf0a7Delay due to large scale deployments.\n\uf0a7Delay due to mobility of deployed nodes.\n\uf0a7Distribution of devices can affect monitoring tasks.\n17\nSource: Arasteh, H., et al. "Iot-based smart cities: A survey." IEEE 16th International Conference on Environment and Electrical \nEngineering (EEEIC), 2016.\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 17}, page_content='IoT Challenges in Smart Cities (contd.)\n\uf0fcLegal and Social aspects\n\uf0a7Services based on user provided information may be subject to local or \ninternational laws.\n\uf0a7Individual and informed consent required for using humans as data \nsources.\n\uf0fcBig data\n\uf0a7Transfer, storage and maintenance of huge volumes of data is expensive.\n\uf0a7Data cleaning and purification is time consuming.\n\uf0a7\nAnalytics on gigantic data volumes is processing intensive.\n18\nSource: Arasteh, H., et al. "Iot-based smart cities: A survey." IEEE 16th International Conference on Environment and Electrical \nEngineering (EEEIC), 2016.\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 18}, page_content='IoT Challenges in Smart Cities (contd.)\n\uf0fcSensor Networks\n\uf0a7Choice of appropriate sensors for individual sensing tasks is crucial.\n\uf0a7Energy planning is crucial.\n\uf0a7Device placement and network architecture is important for reliable \nend-to-end IoT implementation.\n\uf0a7Communication medium and means play an important role in \nseamless function of IoT in smart cities.\n19\nSource: Arasteh, H., et al. "Iot-based smart cities: A survey." IEEE 16th International Conference on Environment and Electrical \nEngineering (EEEIC), 2016.\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 19}, page_content='20\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 20}, page_content='1\nDr. Sudip Misra\nAssociate Professor\nDepartment of Computer Science and Engineering\nIIT KHARAGPUR\nEmail: smisra@sit.iitkgp.ernet.in\nWebsite: http://cse.iitkgp.ac.in/~smisra/\nSmart Cities and Smart Homes – Part II\nIntroduction to Internet of Things'),
# ...
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 77}, page_content='Decision Layer\n18\nFor \nmonitoring\nFor \ncontrol \nof \nsensors\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 78}, page_content='19\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 79}, page_content='1\nDr. Sudip Misra\nAssociate Professor\nDepartment of Computer Science and Engineering\nIIT KHARAGPUR\nEmail: smisra@sit.iitkgp.ernet.in\nWebsite: http://cse.iitkgp.ac.in/~smisra/\nConnected Vehicles – Part II\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 80}, page_content='Intelligent Connected Vehicles (ICVs)\n2\nICV\nIntelligent \nTransportation\nPedestrian\nCommunication \nChannel\nTransport \nInfrastructure\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 81}, page_content='Technological Background\n\uf0fcThe US Department of Transport and Federal Communications \nCommission allocated 75MHz (5850-5925MHz) as the dedicated \nspectrum for ICVs.\n\uf0fcIt is based on Dedicated Short Range Communication (DSRC) \ntechnology.\n\uf0fcIEEE developed IEEE 802.11p and IEEE 1609 as DSRC standards.\n\uf0fcSociety of Automotive Engineers (SAE) came up with SAE J2735 and  \nJ2945 as DSRC standards.\n3\nSource: Li, Yan, et al. "Big wave of the intelligent connected vehicles." China Communications 13.Supplement2 (2016): 27-41.\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 82}, page_content='IEEE 1609 Family\n\uf0fc\nIEEE P1609.0 Draft Standard for Wireless Access in Vehicular Environments (WAVE) -\nArchitecture \n\uf0fc\nIEEE 1609.1-2006 - Trial Use Standard for Wireless Access in Vehicular Environments \n(WAVE) - Resource Manager \n\uf0fc\nIEEE 1609.2 -2006- Trial Use Standard for Wireless Access in Vehicular Environments \n(WAVE) - Security Services for Applications and Management Messages \n\uf0fc\nIEEE 1609.3 -2007 - Trial Use Standard for Wireless Access in Vehicular Environments \n(WAVE) - Networking Services \n\uf0fc\nIEEE 1609.4 -2006- Trial Use Standard for Wireless Access in Vehicular Environments \n(WAVE) - Multi-Channel Operations\n\uf0fc\nIEEE P1609.11 Over-the-Air Data Exchange Protocol for Intelligent Transportation \nSystems (ITS).\n4\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 83}, page_content='DSRC Outline\n5\nSource: Li, Yan, et al. "Big wave of the intelligent connected vehicles." China Communications 13.Supplement2 (2016): 27-41.\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 84}, page_content='Phases of ICV Development\n6\nPhase-1\n• Infotainment service with remote information processing\n• Based on 2G/3G\nPhase-2\n• Intelligent transportation service\n• Based on 4G LTE or DSRC\nPhase-3\n• Vehicles connected to the cloud\nSource: Li, Yan, et al. "Big wave of the intelligent connected vehicles." China Communications 13.Supplement2 (2016): 27-41.\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 85}, page_content='Forward Collision Warning (V2V)\n7\nSource: Li, Yan, et al. "Big wave of the intelligent connected vehicles." China Communications 13.Supplement2 (2016): 27-41.\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 86}, page_content='Vulnerable Road User Safety (V2P)\n8\nSource: Li, Yan, et al. "Big wave of the intelligent connected vehicles." China Communications 13.Supplement2 (2016): 27-41.\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 87}, page_content='VANETs\n9\nDomains\nIn-vehicle\nAd-hoc\nInfrastructure\nSource: Pressas, Andreas, et al. "Connected vehicles in smart cities: interworking from inside vehicles to outside." Sensing, Communication, and \nNetworking (SECON), 2016 13th Annual IEEE International Conference on. IEEE, 2016.\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 88}, page_content='In-Vehicle Domain\n10\n\uf0fcComposed of one or more on-board units (OBUs).\n\uf0fcAdditional presence of Advanced Driver Assistance Systems (ADAS) \nsensors such as-\n\uf0a7cameras\n\uf0a7proximity sensors\n\uf0a7Engine sensors\n\uf0a7Radars\n\uf0a7Actuators\n\uf0fcCommunication is mainly through Controller Area Network (CAN), \nVehicular Powerline Networks (VPLN), and Ethernet.\nSource: Pressas, Andreas, et al. "Connected vehicles in smart cities: interworking from inside vehicles to outside." Sensing, Communication, and \nNetworking (SECON), 2016 13th Annual IEEE International Conference on. IEEE, 2016.\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 89}, page_content='11\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 90}, page_content='Ad-hoc Domain\n12\n\uf0fcComposed of vehicles and road-side units.\n\uf0fcThe vehicles (OBUs) are mobile.\n\uf0fcThe road-side units (RSUs) are static.\n\uf0fcCommunication mode may be either V2V or V2I.\n\uf0fcCommunication through DSRC stack (IEEE 802.11p)\nSource: Pressas, Andreas, et al. "Connected vehicles in smart cities: interworking from inside vehicles to outside." Sensing, Communication, and \nNetworking (SECON), 2016 13th Annual IEEE International Conference on. IEEE, 2016.\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 91}, page_content='13\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 92}, page_content='Infrastructure Domain\n14\n\uf0fcRSUs connected to Internet by means of Gateways.\n\uf0fcIn the presence of RSUs, the vehicles may communicate to the \nInternet via V2I interfaces.\n\uf0fcIn the absence of RSUs, the vehicles may communicate with \neach other or the Internet through cellular networks such as \n3G/4G, LTE, etc.\nSource: Pressas, Andreas, et al. "Connected vehicles in smart cities: interworking from inside vehicles to outside." Sensing, Communication, and \nNetworking (SECON), 2016 13th Annual IEEE International Conference on. IEEE, 2016.\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 93}, page_content='15\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 94}, page_content='16\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 95}, page_content='V2X Communication: Advantages\n\uf0fcIncreased traffic safety.\n\uf0fcIncreased driver safety.\n\uf0fcOptimized time of travel.\n\uf0fcEfficiency of fuel consumption.\n\uf0fcSecure travel.\n\uf0fcEasier drive in low-visibility or unfavorable weather \nconditions.\n17\nSource: Schmidt, Teresa, et al. "Public perception of V2X-technology-evaluation of general advantages, disadvantages and reasons for data \nsharing with connected vehicles." Intelligent Vehicles Symposium (IV), 2016 IEEE. IEEE, 2016.\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 96}, page_content='V2X Communication: Disadvantages\n\uf0fcViolation of privacy.\n\uf0fcLoss of data control.\n\uf0fcCollection of personal data.\n\uf0fcSecond use of data.\n\uf0fcData use by unauthorized entities.\n\uf0fcTracking of movements.\n\uf0fcLocalization of position.\n18\nSource: Schmidt, Teresa, et al. "Public perception of V2X-technology-evaluation of general advantages, disadvantages and reasons for data \nsharing with connected vehicles." Intelligent Vehicles Symposium (IV), 2016 IEEE. IEEE, 2016.\nIntroduction to Internet of Things'),
#  Document(metadata={'producer': '3-Heights(TM) PDF Toolbox API 5.9.1.5 (http://www.pdf-tools.com)', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\Week-10.pdf', 'file_path': '..\\data\\pdf\\Week-10.pdf', 'total_pages': 98, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-07-13T05:24:15+00:00', 'trapped': '', 'modDate': 'D:20200713052415Z', 'creationDate': '', 'page': 97}, page_content='19\nIntroduction to Internet of Things')]

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document
